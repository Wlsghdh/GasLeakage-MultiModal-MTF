# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import normaltest, shapiro, anderson
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
warnings.filterwarnings('ignore')


plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['axes.unicode_minus'] = False

# %%
sensor = pd.read_csv('/data2/project/2025summer/jjh0709/Data/zkwgkjkjn9-2/Gas Sensors Measurements/Gas_Sensors_Measurements.csv')
min_max = pd.read_csv('/data2/project/2025summer/jjh0709/git/GasLeakage-MultiModal-MTF/real.csv')

fig, axes = plt.subplots(8, 1, figsize=(10, 20))
axes = axes.ravel()

def map_m(x):
    Gas = sensor[sensor['Gas']=='NoGas']
    m_Gas = min_max[min_max['Gas']=='NoGas']
    
    Smoke = sensor[sensor['Gas']=='Smoke']
    m_Smoke = min_max[min_max['Gas']=='Smoke']

    Perfume = sensor[sensor['Gas']=='Perfume']
    m_Perfume = min_max[min_max['Gas']=='Perfume']

    Mixture = sensor[sensor['Gas']=='Mixture']
    m_Mixture = min_max[min_max['Gas']=='Mixture']

    _=sns.lineplot(data=Gas,x=np.arange(1600),y='MQ2',ax=axes[0])
    _=axes[0].set_title('Gas_MQ2')
    _=sns.lineplot(data=m_Gas,x=np.arange(1600),y='MQ2',ax=axes[1],color='r')
    _=axes[0].set_title('Gas_MQ2_Min_Max')

    _=sns.lineplot(data=Perfume,x=np.arange(1600),y='MQ2',ax=axes[2])
    _=axes[0].set_title('Perfume_MQ2')
    _=sns.lineplot(data=m_Perfume,x=np.arange(1600),y='MQ2',ax=axes[3],color='r')
    _=axes[0].set_title('Perfume_MQ2_Min_Max')
    
    _=sns.lineplot(data=Smoke,x=np.arange(1600),y='MQ2',ax=axes[4])
    _=axes[0].set_title('Smoke_MQ2')
    _=sns.lineplot(data=m_Smoke,x=np.arange(1600),y='MQ2',ax=axes[5],color='r')
    _=axes[0].set_title('Smoke_MQ2_Min_Max')
    
    _=sns.lineplot(data=Mixture,x=np.arange(1600),y='MQ2',ax=axes[6])
    _=axes[0].set_title('Mixture_MQ2')
    _=sns.lineplot(data=m_Mixture,x=np.arange(1600),y='MQ2',ax=axes[7],color='r')
    _=axes[0].set_title('Mixture_MQ2_Min_Max')



    

map_m('MQ3')
fig.tight_layout()

# %%
mm_Gas= pd.read_csv('/data2/project/2025summer/jjh0709/git/GasLeakage-MultiModal-MTF/normalized_NoGas2.csv')
mm_Perfume = pd.read_csv('/data2/project/2025summer/jjh0709/git/GasLeakage-MultiModal-MTF/normalized_Perfume.csv')
mm_Smoke = pd.read_csv('/data2/project/2025summer/jjh0709/git/GasLeakage-MultiModal-MTF/normalized_Smoke3.csv')
mm_Mixture = pd.read_csv('/data2/project/2025summer/jjh0709/git/GasLeakage-MultiModal-MTF/normalized_Mixture.csv')
sensor = pd.read_csv('/data2/project/2025summer/jjh0709/Data/zkwgkjkjn9-2/Gas Sensors Measurements/Gas_Sensors_Measurements.csv')

Gas = sensor[sensor['Gas']=='NoGas']
#Gas = Gas[Gas['Serial Number']>=58]

Smoke = sensor[sensor['Gas']=='Smoke']
#Smoke = Smoke[Smoke['Serial Number']>=10]

Perfume = sensor[sensor['Gas']=='Perfume']

Mixture = sensor[sensor['Gas']=='Mixture']



fig, axes = plt.subplots(8, 1, figsize=(30, 20))
axes = axes.ravel()

def map_s(x):
    print(len(mm_Gas),len(mm_Perfume),len(mm_Smoke),len(mm_Mixture))
    _=sns.lineplot(data=Gas,x=np.arange(1600),y='MQ2',ax=axes[0])
    _=axes[0].set_title('Gas_MQ2')
    _=sns.lineplot(data=mm_Gas,x=np.arange(1600),y='MQ2',ax=axes[1],color='r')
    _=axes[1].set_title('Gas_MQ2_Min_Max')

    _=sns.lineplot(data=Perfume,x=np.arange(1600),y='MQ2',ax=axes[2])
    _=axes[2].set_title('Perfume_MQ2')
    _=sns.lineplot(data=mm_Perfume,x=np.arange(1600),y='MQ2',ax=axes[3],color='r')
    _=axes[3].set_title('Perfume_MQ2_Min_Max')
    
    _=sns.lineplot(data=Smoke,x=np.arange(1600),y='MQ2',ax=axes[4])
    _=axes[4].set_title('Smoke_MQ2')
    _=sns.lineplot(data=mm_Smoke,x=np.arange(1600),y='MQ2',ax=axes[5],color='r')
    _=axes[5].set_title('Smoke_MQ2_Min_Max')
    
    _=sns.lineplot(data=Mixture,x=np.arange(1600),y='MQ2',ax=axes[6])
    _=axes[6].set_title('Mixture_MQ2')
    _=sns.lineplot(data=mm_Mixture,x=np.arange(1600),y='MQ2',ax=axes[7],color='r')
    _=axes[7].set_title('Mixture_MQ2_Min_Max')  

    NoGas_starts = [0,58, 82, 136, 188, 225, 277, 344, 409, 471, 545, 619, 685, 753, 819, 887, 969, 1049, 1130, 1222,1304, 1393, 1465, 1531]
    NoGas_ends = [0,58,81, 135, 187, 224, 276, 343,409 ,473, 544, 618, 684, 752, 818, 890, 971, 1051, 1129, 1222,1303, 1392, 1464, 1530, 1600]
    
    Perfume_starts = [0, 95, 162, 229, 312, 379, 432, 487, 541, 590, 636, 690, 740, 795, 844, 884, 923, 989, 1030, 1061, 1108, 1160, 1201, 1274, 1333, 1374, 1456, 1539]
    Perfume_ends = [94, 161, 228, 311, 378, 431, 486, 540, 589, 635, 689, 739, 794, 843, 883, 922, 988, 1029, 1060, 1107, 1159, 1200, 1273, 1332, 1373, 1455, 1538, 1599]
    
    Mixture_starts = [0, 56, 125, 233, 345, 401, 462, 554, 605, 726, 779, 841, 895, 990, 1132, 1248, 1381, 1557]
    Mixture_ends = [55, 120, 232, 344, 400, 461, 555, 604, 725, 778, 840, 894, 989, 1131, 1247, 1380, 1556, 1600]
    Smoke_starts = [10, 44, 102, 199, 254, 331, 441, 512, 610, 704, 827, 952, 1019, 1096, 1177, 1252, 1325, 1402, 1460, 1535]
    Smoke_ends = [43, 101, 198, 253, 330, 440, 511, 609, 703, 826, 951, 1018, 1095, 1176, 1251, 1324, 1401, 1459, 1534, 1599]

    for i in range(2):
        for j in NoGas_ends:
            #j = j-58
            _=axes[i].axvline(x=j,color='k',linestyle='--',linewidth=1)

    
    for i in range(2,4):
        for j in Perfume_starts:
            _=axes[i].axvline(x=j,color='k',linestyle='--',linewidth=2)

            
    for i in range(4,6):
        for j in Smoke_starts:
            
            _=axes[i].axvline(x=j,color='k',linestyle='--',linewidth=2)    
    for i in range(6,8):
        for j in Mixture_starts:
            _=axes[i].axvline(x=j,color='k',linestyle='--',linewidth=2)               
    
map_s('MQ3')
fig.tight_layout()
# Out:
# 1600 1600 1600 1600
